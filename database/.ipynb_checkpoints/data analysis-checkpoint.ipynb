# %%
import numpy as np
import cv2

# %% [markdown]
# # Face Pic

# %%
i = 0

# %%
a = np.array(np.load('etc/face_container_2.npy'), dtype=np.uint8)

# %%
a.shape
# Out:
# (1, 112, 112, 3)

# %%
cv2.imshow('im', a[0])
# cv2.imshow('im1', a[1])
# cv2.imshow('im2', a[2])
# cv2.imshow('im3', a[3])
# cv2.imshow('im4', a[4])

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Emotion

# %%
b = np.load('etc/emotion_container_1.npy', allow_pickle=True)

# %%
b = b.tolist()

# %%
b
# Out:
# [[' ',
#   ' ',
#   ' ',
#   ' ',
#   'Sad',
#   'Neu',
#   ' ',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   'Neu',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   ' ',
#   'Hap',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   ' ',
#   ' ',
#   ' ',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   ' ',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   ' ',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Neu',
#   'Neu',
#   'Hap',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   ' ',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Neu',
#   ' ',
#   'Neu',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   'Neu',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Neu',
#   'Hap',
#   'Hap',
#   'Neu',
#   'Hap',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   ' ',
#   ' ',
#   ' ',
#   'Neu',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad'],
#  ['Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   'Hap',
#   ' ',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Hap',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Hap',
#   'Sad',
#   ' ',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Neu',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Hap',
#   'Hap',
#   'Hap',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Neu',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Neu',
#   'Neu',
#   'Neu',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   ' ',
#   ' ',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad',
#   'Sad']]

# %%
i = 0

# %%
sum_emotion = b[i].count('Sad') + b[i].count('Hap') + b[i].count('Neu')
hap_per, sad_per, neu_per = round(b[i].count('Hap') * 100/ sum_emotion, 2), round(b[i].count('Sad') * 100/ sum_emotion, 2), round(b[i].count('Neu') * 100/ sum_emotion, 2)
print('Happy percent: {}%; Sad percent: {}%; Neutral percent: {}%'.format(hap_per, sad_per, neu_per))
# Out:
# Happy percent: 31.11%; Sad percent: 62.04%; Neutral percent: 6.85%

# %% [markdown]
# # Duration

# %%
hour = 15
minute = 20
second = 3

# %%
c = np.load('etc/duration_container_1.npy', allow_pickle=True)

# %%
i = 0

# %%
time_seq = []
for j in c[i]:
    s = second + j // 30
    m = minute + s // 60
    s %= 60
    h = hour + m // 60
    m %= 60
    time_seq.append((h, m, s))

# %%
print(['{}:{}:{}'.format(time_seq[j][0], time_seq[j][1], time_seq[j][2]) for j in range(len(time_seq))][0])
print(['{}:{}:{}'.format(time_seq[j][0], time_seq[j][1], time_seq[j][2]) for j in range(len(time_seq))][-1])
# Out:
# 15:20:3
# 15:20:32

# %%
# Khai báo
def abc(x, y):
    return min(x, y)

# Sử dụng
print('Kết quả: ', abc(3, 4))
# Out:
# Kết quả:  3

# %%
# Khai báo
def xyz(x, y):
    min(x, y)

# Sử dụng
print('Kết quả: ', xyz(3, 4))
# Out:
# Kết quả:  None

# %%
s = int(input())
# Out:
#  5

# %%
s
# Out:
# 5

# %%
a = input(5.6)
b = input()
# Out:
# 5.6 5.2
#  3
